# %% [markdown]
# In This NoteBook there are two problems are solved by Linear Regression.

# %%
import numpy as np 
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
dataframe = pd.read_csv("USA_Housing.csv")

# %%
dataframe.head(10)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
# 5      80175.754159             4.988408                   6.104512
# 6      64698.463428             6.025336                   8.147760
# 7      78394.339278             6.989780                   6.620478
# 8      59927.660813             5.362126                   6.393121
# 9      81885.927184             4.423672                   8.167688
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# ...

# %%
dataframe['Price']
# Out:
# 0       1.059034e+06
# 1       1.505891e+06
# 2       1.058988e+06
# 3       1.260617e+06
# 4       6.309435e+05
#             ...
# 4995    1.060194e+06
# 4996    1.482618e+06
# 4997    1.030730e+06
# 4998    1.198657e+06
# 4999    1.298950e+06
# Name: Price, Length: 5000, dtype: float64

# %%
dataframe.tail(10)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4990      52723.876555             5.452237                   8.124571
# 4991      74102.191890             5.657841                   7.683993
# 4992      87499.125743             6.403473                   4.836091
# 4993      69639.140896             5.007510                   7.778375
# 4994      73060.846226             5.293682                   6.312253
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 4990                          6.39     14802.088438  4.795006e+05
# ...

# %%
#mean of price 

dataframe.Price.mean()
# Out:
# 1232072.654142357

# %%
# values 
dataframe.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
dataframe.isnull()
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0                False                False                      False
# 1                False                False                      False
# 2                False                False                      False
# 3                False                False                      False
# 4                False                False                      False
# ...                ...                  ...                        ...
# 4995             False                False                      False
# 4996             False                False                      False
# 4997             False                False                      False
# 4998             False                False                      False
# 4999             False                False                      False
#
#       Avg. Area Number of Bedrooms  Area Population  Price  Address
# ...

# %%
dataframe.iloc[0:2]
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...

# %%
dataframe.loc[0:4]
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
a=dataframe.loc[:, 'Area Population']

# %%
a
# Out:
# 0       23086.800503
# 1       40173.072174
# 2       36882.159400
# 3       34310.242831
# 4       26354.109472
#             ...
# 4995    22837.361035
# 4996    25616.115489
# 4997    33266.145490
# 4998    42625.620156
# 4999    46501.283803
# Name: Area Population, Length: 5000, dtype: float64

# %%
dataframe.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
sns.pairplot(dataframe)

# %%
sns.displot(dataframe['Price'])

# %%
sns.barplot(dataframe["Price"])
# Out:
# /home/automatonai/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price'>

# %%
sns.heatmap(dataframe.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
dataframe.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
x = dataframe[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population']]

# %%
dataframe.drop(['Address'],axis=1, inplace=True)

# %%
dataframe
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price
# ...

# %%
x = dataframe.drop(['Price'], axis =1)

# %%
dataframe.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05

# %%
y = dataframe[['Price']]

# %%
from sklearn import model_selection

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.4,random_state = 101)

# %%
#importing model

from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
# Out:
# [-2640159.7968527]

# %%
coffe1 = lm.coef_
type(coffe1)
# Out:
# numpy.ndarray

# %%
list2 = list(x_train.columns)
list2
# Out:
# ['Avg. Area Income',
#  'Avg. Area House Age',
#  'Avg. Area Number of Rooms',
#  'Avg. Area Number of Bedrooms',
#  'Area Population']

# %%
list1 = []
for i in coffe1:
    print(i)
    for j in i:
        print(j)
        list1.append(j)
# Out:
# [2.15282755e+01 1.64883282e+05 1.22368678e+05 2.23380186e+03
#  1.51504200e+01]
# 21.528275528904796
# 164883.28202690973
# 122368.67802721163
# 2233.801864122619
# 15.15041998407105

# %%
list1
# Out:
# [21.528275528904796,
#  164883.28202690973,
#  122368.67802721163,
#  2233.801864122619,
#  15.15041998407105]

# %%
c = pd.DataFrame(data = list1)

# %%
c
# Out:
#                0
# 0      21.528276
# 1  164883.282027
# 2  122368.678027
# 3    2233.801864
# 4      15.150420

# %%
c['Coffe'] = list2

# %%
c
# Out:
#                0                         Coffe
# 0      21.528276              Avg. Area Income
# 1  164883.282027           Avg. Area House Age
# 2  122368.678027     Avg. Area Number of Rooms
# 3    2233.801864  Avg. Area Number of Bedrooms
# 4      15.150420               Area Population

# %%
c.rename(columns = {0 :'coffe', 'Coffe':'Names'}, inplace = True)

# %%
c
# Out:
#            coffe                         Names
# 0      21.528276              Avg. Area Income
# 1  164883.282027           Avg. Area House Age
# 2  122368.678027     Avg. Area Number of Rooms
# 3    2233.801864  Avg. Area Number of Bedrooms
# 4      15.150420               Area Population

# %%
# Predictions

prediction = lm.predict(x_test)

# %%
prediction
# Out:
# array([[1260960.70567627],
#        [ 827588.75560329],
#        [1742421.24254344],
#        ...,
#        [ 372191.40626917],
#        [1365217.15140898],
#        [1914519.5417888 ]])

# %%
plt.scatter(y_test,prediction)

# %%
sns.displot(y_test-prediction)

# %% [markdown]
# evaluating the model

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test, prediction)
# Out:
# 82288.22251914942

# %%
metrics.mean_squared_error(y_test, prediction)
# Out:
# 10460958907.208977

# %%
np.sqrt(metrics.mean_squared_error(y_test, prediction))
# Out:
# 102278.82922290897

# %%
type(np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# numpy.float64

# %% [markdown]
# # Example of LinearRegression

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("Ecommerce_Customers.csv")

# %%
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
df.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
import seaborn as sns

# %%
sns.jointplot(data = df, x = "Time on Website", y = "Yearly Amount Spent" )
#jointplot use to join and plot the two columns in a single graph

# %%
sns.jointplot(x="Time on App", y = "Length of Membership", kind = "hex", data = df)

# %%
sns.pairplot(df)

# %%
#Length of Membership shown correlation thats why below

# %%
sns.lmplot(x = "Length of Membership", y = "Yearly Amount Spent" , data = df)

# %%
df.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
x = df[['Avg. Session Length', 'Time on App',
       'Time on Website', 'Length of Membership']]

# %%
y = df['Yearly Amount Spent']

# %%
x
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
# [500 rows x 4 columns]

# %%
y
# Out:
# 0      587.951054
# 1      392.204933
# 2      487.547505
# 3      581.852344
# 4      599.406092
#           ...
# 495    573.847438
# 496    529.049004
# 497    551.620145
# 498    456.469510
# 499    497.778642
# Name: Yearly Amount Spent, Length: 500, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3,train_size=None, random_state = 101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lmm = LinearRegression()

# %%
lmm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lmm.coef_
# Out:
# array([25.98154972, 38.59015875,  0.19040528, 61.27909654])

# %%
#prediction
lmm.predict(x_test)

# %%
prediction
# Out:
# array([456.44186104, 402.72005312, 409.2531539 , 591.4310343 ,
#        590.01437275, 548.82396607, 577.59737969, 715.44428115,
#        473.7893446 , 545.9211364 , 337.8580314 , 500.38506697,
#        552.93478041, 409.6038964 , 765.52590754, 545.83973731,
#        693.25969124, 507.32416226, 573.10533175, 573.2076631 ,
#        397.44989709, 555.0985107 , 458.19868141, 482.66899911,
#        559.2655959 , 413.00946082, 532.25727408, 377.65464817,
#        535.0209653 , 447.80070905, 595.54339577, 667.14347072,
#        511.96042791, 573.30433971, 505.02260887, 565.30254655,
#        460.38785393, 449.74727868, 422.87193429, 456.55615271,
#        598.10493696, 449.64517443, 615.34948995, 511.88078685,
#        504.37568058, 515.95249276, 568.64597718, 551.61444684,
#        356.5552241 , 464.9759817 , 481.66007708, 534.2220025 ,
#        256.28674001, 505.30810714, 520.01844434, 315.0298707 ,
#        501.98080155, 387.03842642, 472.97419543, 432.8704675 ,
# ...

# %%
import matplotlib.pyplot as plt

# %%
# visualization of predicted values

plt.scatter(y_test, prediction)
plt.xlabel('Y test(True values)')
plt.ylabel('Predicted Values')
plt.show()

# %%
# evaluation of a model

# %%
from sklearn import metrics

# %%
print("MAE", metrics.mean_absolute_error(y_test,prediction))
# Out:
# MAE 7.228148653430826

# %%
print("MSE", metrics.mean_squared_error(y_test,prediction))
# Out:
# MSE 79.81305165097427

# %%
print("MRSE",np.sqrt(metrics.mean_squared_error(y_test,prediction)))
# Out:
# MRSE 8.933815066978624

# %%
sns.displot( y_test-prediction)

# %% [markdown]
# # Conclusion

# %%
cdf = pd.DataFrame(lmm.coef_,x.columns,columns = ["coiff"])

# %%
cdf
# Out:
#                           coiff
# Avg. Session Length   25.981550
# Time on App           38.590159
# Time on Website        0.190405
# Length of Membership  61.279097
